# %% [markdown]
# # Práctica 11 — ¿Quiénes son nuestros usuarios?
#
# Trabajás como analista en el equipo de **Growth de PedidosYa Argentina**, y las campañas de cupones son una de las herramientas más usadas del equipo. La situación ya la viste en clase: tu entregable es una recomendación concreta para la próxima campaña.
#
# **Con qué contás:** `usuarios_pedidosya.csv` — la base de usuarios de los últimos dos años.
#
# **La regla de la práctica:** cada cosa que afirmes, mostrala. Todo hallazgo y toda decisión van acompañados de un gráfico o una tabla que los respalde.

# %% [markdown]
# ## 1. El negocio
#
# Antes de tocar código, contestá en texto:
#
# - ¿Cuál es el problema? (una frase, como se la dirías al CFO)
# - ¿Qué le vas a preguntar a los datos?
# - ¿Esto es supervisado o no supervisado? ¿Por qué?

# %% [markdown]
# **Tus respuestas:**
#
# -

# %% [markdown]
# ## 2. Los datos
#
# Cargá la base y conocela: ¿podés confiar en lo que te dieron?
#
# Mostrá **como mínimo dos gráficos** que ayuden a entender a los usuarios, y abajo de cada uno contá en una línea qué ves.

# %% [markdown]
# **Qué encontré:**
#
# -

# %% [markdown]
# ## 3. Preparación
#
# Dejá la base lista para el modelo. Tres decisiones, todas tuyas:
#
# - ¿Qué hacés con lo raro que encontraste? **Mostralo en un gráfico antes de decidir**: lo que vas a tocar, primero se ve.
# - ¿Con qué columnas vas a segmentar?
# - ¿Hace falta transformar algo antes de modelar?
#
# Anotá cada decisión con su porqué.

# %% [markdown]
# **Mis decisiones y por qué:**
#
# -

# %% [markdown]
# ## 4. El modelo — K-Means
#
# ¿Cuántos grupos de usuarios hay? El algoritmo no lo decide: lo decidís vos, **con evidencia en un gráfico** — no a ojo.

# %% [markdown]
# **Mi K y por qué:**
#
# -

# %% [markdown]
# ## 5. Evaluación y decisión
#
# Poneles cara a los grupos y cerrá el trabajo:
#
# - ¿Qué hace distinto a cada grupo? **Mostralo en gráficos** que cualquiera de Growth lea en diez segundos, y bautizá a cada grupo con un nombre que se entienda solo.
# - Tu recomendación, en 3 a 5 bullets de negocio. Ojo: el presupuesto alcanza para **una sola campaña dirigida** — no para toda la base. ¿A qué grupo va, y con qué oferta? ¿A quién no le mandás nada? ¿Cómo sabés en un mes si funcionó?

# %% [markdown]
# **Mis segmentos, con nombre y una línea cada uno:**
#
# -

# %% [markdown]
# **Mi recomendación:**
#
# -

# %% [markdown]
# ## 6. ¿Te sobró tiempo?
#
# En la teórica viste otros dos métodos: el clustering jerárquico (dendrograma) y DBSCAN. Corré uno sobre tus mismas variables: ¿te cuenta algo que K-Means no te mostró?
